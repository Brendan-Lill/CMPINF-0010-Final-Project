# %% [markdown]
# # Final Notebook - Brendan Lill
#
# This Notebook uses a WPRDC data set that has collected all of the fire reports since 2015. Here, each neighborhood is assessed by how many total fire reports have occured in them, with fewer being better and vice versa.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
df = pd.read_csv("Fire-Incidents.csv")
df.head()
neighborhood_dict = dict()
for index, row in df.iterrows():
    if pd.notna(row.iloc[9]):
        if row.iloc[9] in neighborhood_dict:
            neighborhood_dict[row.iloc[9]] += 1
        else:
            neighborhood_dict[row.iloc[9]] = 1
for k, v in sorted(neighborhood_dict.items(), key=lambda x: x[1], reverse=True):
    print(k,":", v)
# Out:
# Carrick : 328
# South Side Flats : 307
# Central Business District : 304
# Squirrel Hill South : 281
# Hazelwood : 264
# Mount Washington : 238
# East Liberty : 230
# Homewood South : 209
# Brookline : 209
# Lincoln-Lemington-Belmar : 206
# Knoxville : 205
# Shadyside : 201
# Homewood North : 197
# Bloomfield : 191
# Sheraden : 181
# Perry South : 174
# East Hills : 166
# Beechview : 163
# Brighton Heights : 163
# Marshall-Shadeland : 162
# Bluff : 159
# East Allegheny : 142
# Squirrel Hill North : 142
# Beltzhoover : 141
# Central Northside : 139
# Allentown : 136
# North Oakland : 136
# Larimer : 130
# Greenfield : 129
# Garfield : 121
# Spring Hill-City View : 119
# Perry North : 117
# Crawford-Roberts : 117
# South Side Slopes : 115
# Middle Hill : 110
# South Oakland : 104
# Central Oakland : 104
# North Shore : 91
# Crafton Heights : 89
# Troy Hill : 89
# Terrace Village : 88
# Highland Park : 86
# Manchester : 84
# Strip District : 80
# Central Lawrenceville : 80
# ...

# %%
data_series = pd.Series(neighborhood_dict)
sorted_series = data_series.sort_values()
bottom_10 = sorted_series.head(10)
top_10 = sorted_series.tail(10)
top_10.plot(kind='bar')
plt.title('Top 10 Highest Fire Neighborhoods')
plt.xlabel('Neighborhood')
plt.ylabel('Fire Reports')
plt.show()
bottom_10.plot(kind='bar')
plt.title('Top 10 Lowest Fire Neighborhoods')
plt.xlabel('Neighborhood')
plt.ylabel('Fire Reports')
plt.show()
